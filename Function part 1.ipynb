# %%
def am33():
    print('gm')

# %%
def am33():
    print('gm')
am33()
# Out:
# gm

# %%
def add(x,y):
    c=x+y
    print(c)
add(4,7)
# Out:
# 11

# %%
def greet(x,y):
    c=x+y
    print(c)
greet(4,7)
# Out:
# 11

# %%
def add(x,y):
    c=x+y
    print(c)
add(4,7)
def greet(x,y):
    c=x+y
    print(c)
greet(4,7)
# Out:
# 11
# 11

# %%
def sub(x,y):
    c=y -x
    print(c)
sub(4,7)
# Out:
# 3

# %%
def add_sub(x,y):
    c=y -x
    print(c)
add_sub(4,7)
# Out:
# 3

# %%
def add_sub(x,y):
    c=y -x
    h=y+x
    print(c)
    print(h)
add_sub(4,7)
# Out:
# 3
# 11

# %%
def add_sub(x,y):
    c=y -x
    h=y+x
    return c,h
    
add_sub(4,7)
# Out:
# (3, 11)

# %% [markdown]
# # formal argument  actial argument

# %%
def person (name, age):
    print(name)
    print(age)
person('nit',88)
# Out:
# nit
# 88

# %%
def person (name, age): #because there are 3 argument in present instant of 2
    print(name)
    print(age)
person('nit',88, 98)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 4
#       2     print(name)
#       3     print(age)
# ----> 4 person('nit',88, 98)
#
# TypeError: person() takes 2 positional arguments but 3 were given

# %%
def person (name, age):
    print(name)
    print(age)
person(88,'nit')
# Out:
# 88
# nit

# %% [markdown]
# # Keyword argument

# %%
def person (name, age):
    print(name)
    print(age+8)
person('nit',88)
# Out:
# nit
# 96

# %%
def person (name, age):
    print(name+ 'add')
    print(age)
person('nit',88)
# Out:
# nitadd
# 88

# %%
def person (name, age):
    print(name+"ajck son|")
    print(age+999)
person(name='nit',age=88)
# Out:
# nitajck son|
# 1087

# %%
def person (name, age):
    print(name+"ajck son|")
    print(age-2)
person(name='nit',age=88)
# Out:
# nitajck son|
# 86

# %% [markdown]
# # variable length argument

# %%
def sum(a,b):
    c = a+b
    return c

sum(4,5)
# Out:
# 9

# %%
def sum(a,b):
    c = a+b
    return c

sum(4,5,9,8,8,6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 5
#       2     c = a+b
#       3     return c
# ----> 5 sum(4,5,9,8,8,6)
#
# TypeError: sum() takes 2 positional arguments but 6 were given

# %%
def sum (a,b,c,d):
    z=a+b+c+d
    return z

sum(4,5,6,8)
# Out:
# 23

# %%
def sum(a,*b): 
    c = a+b
    return c

sum(4,5,6,8,2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 5
#       2     c = a+b
#       3     return c
# ----> 5 sum(4,5,6,8,2)
#
# Cell In[32], line 2, in sum(a, *b)
#       1 def sum(a,*b):
# ----> 2     c = a+b
#       3     return c
#
# TypeError: unsupported operand type(s) for +: 'int' and 'tuple'

# %%
def sum(a,*b):
    #c = a+b
    print(a)
    print(b)

sum(4,5,6,8,2)
# Out:
# 4
# (5, 6, 8, 2)

# %%
def sum(a,*d): #argument 1 must be str, not int
    print(type(a))
    print(type(*d))

sum(12,23,2,44)
# Out:
# <class 'int'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 5
#       2     print(type(a))
#       3     print(type(*d))
# ----> 5 sum(12,23,2,44)
#
# Cell In[39], line 3, in sum(a, *d)
#       1 def sum(a,*d):
#       2     print(type(a))
# ----> 3     print(type(*d))
#
# TypeError: type.__new__() argument 1 must be str, not int

# %%
def sum(a,*d):
    print(type(a))
    print(type(d))

sum(12,23,2,44)
# Out:
# <class 'int'>
# <class 'tuple'>

# %%
def sum(a,*b):

    print(a)
    print(b)

sum(4,5,6,8,2)
# Out:
# 4
# (5, 6, 8, 2)

# %%
def sum(a,*b):

    print(a)
    print(*b)

sum(4,5,6,8,2)
# Out:
# 4
# 5 6 8 2

# %%
def sum(a,*b):

    print(a)
    print(b)

sum(4,5,6,8,2,'jack')
# Out:
# 4
# (5, 6, 8, 2, 'jack')

# %%
def sum(a,**b):

    print(a)
    print(b)

sum(4,5,6,8,2,'jack')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[61], line 6
#       3     print(a)
#       4     print(b)
# ----> 6 sum(4,5,6,8,2,'jack')
#
# TypeError: sum() takes 1 positional argument but 6 were given

# %%
def person(name, *data):
    print(name)
    print(data)

person('buri buri',14, 'zimon', 45)
# Out:
# buri buri
# (14, 'zimon', 45)

# %%
def person(name,*data):
    print('name')
    print(data)

person ('zimon',age=15, homeplace='mount fuji', mob=898437589)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 5
#       2     print('name')
#       3     print(data)
# ----> 5 person ('zimon',age=15, homeplace='mount fuji', mob=898437589)
#
# TypeError: person() got an unexpected keyword argument 'age'

# %%
def person(name,**data):
    print('name')
    print(data)

person ('zimon',age=15, homeplace='mount fuji', mob=898437589)
# Out:
# name
# {'age': 15, 'homeplace': 'mount fuji', 'mob': 898437589}

# %% [markdown]
# # global variable vs local variable

# %%
a = 10
print(a)
# Out:
# 10

# %%
a=10
def som():
    b=14

    print('in function',b)
    print('out function',a)

# %%
a=10
def som():
    b=14
    print('in function',b)
print('out function',a)
# Out:
# out function 10

# %%
a=10
def som():
    b=14
    print('out function',a)
print('in function',b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[86], line 5
#       3     b=14
#       4     print('out function',a)
# ----> 5 print('in function',b)
#
# NameError: name 'b' is not defined

# %%
a=10
def som():
    b=14
    print('out function',a)
som()
print('in function',b)
# Out:
# out function 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[89], line 6
#       4     print('out function',a)
#       5 som()
# ----> 6 print('in function',b)
#
# NameError: name 'b' is not defined

# %%
a=10
def som():
    a=14
print('in function',a)

print('out function',a)
# Out:
# in function 10
# out function 10

# %%
a=10
def som():
    b=14
    print('in function',b)
    som()
print('out function',a)
# Out:
# out function 10

# %%
a=10
def som():
    b=14
    print('in function',b)
som()
print('out function',a)
# Out:
# in function 14
# out function 10

# %%
# if i want to define global variabel inside the function 
a = 10  

def something():
    global a 
    b = 15 # 15 is converted to local when user assigned global a 
    print('in function',b)
    print('gloabl variable', a)
something()
print('out function',a)
# Out:
# in function 15
# gloabl variable 10
# out function 10

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
a=21

def som():
    global a
    b=15
    print('in function',b)
som()
    print('out function',a)|
# Out:
#   Cell In[95], line 8
#     print('out function',a)|
#     ^
# IndentationError: unexpected indent

# %%
a=21

def som():
    global a
    b=15
    print('in function',b)
    print('global variable',a)
som()
print('out function',a)|
# Out:
#   Cell In[75], line 9
#     print('out function',a)|
#                              ^
# SyntaxError: invalid syntax

# %% [markdown]
# # 3rd

# %%
def fact(n):
    f=1
    for i in range(1,n+1):
        f=f*1
        print(f)
fact(7)
# Out:
# 1
# 1
# 1
# 1
# 1
# 1
# 1

# %%
def fact(n):
    f=1
    for i in range(1,n+1):
        f=f*1
        print(f)
fact(7)
# Out:
# 1
# 1
# 1
# 1
# 1
# 1
# 1

# %%
def wish():
    print('hi')
    print('hlo')
wish()
# Out:
# hi
# hlo

# %%
def wish():
    print('buri buri')
    print('zimon')
    wish()
wish()
# Out:
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# buri buri
# zimon
# ...

# %%
import sys
sys.getrecursionlimit()
# Out:
# 3000

# %%
import sys
sys.setrecursionlimit(200)
print(sys.getrecursionlimit())
# Out:
# 200

# %%
import sys
sys.setrecursionlimit(90)
print(sys.getrecursionlimit())

i=0
def wish():
    global i
    i =+ 1
    print('hi',i)
    wish()
wish()
# Out:
# 90
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "C:\Users\mohur\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#     ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\mohur\AppData\Local\Temp\ipykernel_29440\1684358945.py", line 11, in <module>
#     wish()
#     ~~~~^^
# ...

# %%
def fact (n):
    if n==0:
        return 1
    return n * fact(n-1)

result= fact(5)
result
# Out:
# 120

# %%
import sys
sys.setrecursionlimit(90)
print(sys.getrecursionlimit())

i=0
def wish():
    global i
    i =+ 1
    print('hi',i)
    wish()
wish()
# Out:
# 90
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# hi 1
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "C:\Users\mohur\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#     ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\mohur\AppData\Local\Temp\ipykernel_29440\1684358945.py", line 11, in <module>
#     wish()
#     ~~~~^^
# ...

# %%
def square (a):
    return a*a
    result = square(5)

print(result)
# Out:
# 120

# %%
f= lambda a : a * a
result=f(5)
print(result)
# Out:
# 25

# %%
f = lambda a, b : a+b
f1 = lambda a, b : a-b

result = f(1,4)
result1 = f1(1,4)
print (result)
print (result1)
# Out:
# 5
# -3

# %%
f = lambda a, b : a+b
f1 = lambda a, b : a-b
f2 = lambda a, b : a*b

result = f(1,4)
result1 = f1(1,4)
result2 = f(1,4)

print (result)
print (result1)
print (result2)
# Out:
# 5
# -3
# 5
