# %% [markdown]
# # Tuple

# %%
t=()
t
# Out:
# ()

# %%
type(t)
# Out:
# tuple

# %%
t=(10,20,30,40,50,60,100)
t
# Out:
# (10, 20, 30, 40, 50, 60, 100)

# %%
for i in t:
    print (i)
# Out:
# 10
# 20
# 30
# 40
# 50
# 60
# 100

# %%
t2= t*4
t2
# Out:
# (10,
#  20,
#  30,
#  40,
#  50,
#  60,
#  100,
#  10,
#  20,
#  30,
#  40,
#  50,
#  60,
#  100,
#  10,
#  20,
#  30,
#  40,
#  50,
#  60,
#  100,
#  10,
#  20,
#  30,
#  40,
#  50,
#  60,
#  100)

# %%
t2
# Out:
# (10,
#  20,
#  30,
#  40,
#  50,
#  60,
#  100,
#  10,
#  20,
#  30,
#  40,
#  50,
#  60,
#  100,
#  10,
#  20,
#  30,
#  40,
#  50,
#  60,
#  100,
#  10,
#  20,
#  30,
#  40,
#  50,
#  60,
#  100)

# %%
print (t2)
# Out:
# (10, 20, 30, 40, 50, 60, 100, 10, 20, 30, 40, 50, 60, 100, 10, 20, 30, 40, 50, 60, 100, 10, 20, 30, 40, 50, 60, 100)

# %%
t
# Out:
# (10, 20, 30, 40, 50, 60, 100)

# %%
t.index(3) # becaue 3 is not pressent in tr
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 t.index(3)
#
# ValueError: tuple.index(x): x not in tuple

# %%
t.index(100)
# Out:
# 6

# %%
t2.index (60)
# Out:
# 5

# %%
t
# Out:
# (10, 20, 30, 40, 50, 60, 100)

# %%
t.count(30)
# Out:
# 1

# %%
t2.count(100)
# Out:
# 4

# %% [markdown]
# # SET

# %%
s={}
s
# Out:
# {}

# %%
type (s)
# Out:
# dict

# %%
s1=set()
s1
# Out:
# set()

# %%
s={10,30,20,90,80,40,50}
s
# Out:
# {10, 20, 30, 40, 50, 80, 90}

# %%
s.add(69)

# %%
s
# Out:
# {10, 20, 30, 40, 50, 69, 80, 90}

# %%
s.add('romiyo')

# %%
s
# Out:
# {10, 20, 30, 40, 50, 69, 80, 90, 'romiyo'}

# %%
s1=s.copy()
s1
# Out:
# {10, 20, 30, 40, 50, 69, 80, 90, 'romiyo'}

# %%
s1
# Out:
# {10, 20, 30, 40, 50, 69, 80, 90, 'romiyo'}

# %%
s.clear()

# %%
s
# Out:
# set()

# %%
s2=s1.copy()
s2
# Out:
# {10, 20, 30, 40, 50, 69, 80, 90, 'romiyo'}

# %%
s2
# Out:
# {10, 20, 30, 40, 50, 69, 80, 90, 'romiyo'}

# %%
s1.remove(90)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 s1.remove(90)
#
# KeyError: 90

# %%
s1
# Out:
# {10, 20, 30, 40, 50, 69, 80, 'romiyo'}

# %%
s1.discard(10110)# it never accurs errror
s1
# Out:
# {10, 20, 40, 50, 69, 80, 'romiyo'}

# %%
s1.discard(30)

# %%
s1
# Out:
# {10, 20, 40, 50, 69, 80, 'romiyo'}

# %% [markdown]
# # Set operator
# UNION

# %%
a={20,30,20,40,90,50,90,60}
a
# Out:
# {20, 30, 40, 50, 60, 90}

# %%
b=a.copy()
b
# Out:
# {20, 30, 40, 50, 60, 90}

# %%
b
# Out:
# {20, 30, 40, 50, 60, 90}

# %%
b.add(70)

# %%
b
# Out:
# {20, 30, 40, 50, 60, 70, 90}

# %%
a.union( b)
# Out:
# {20, 30, 40, 50, 60, 70, 90}

# %%
a
# Out:
# {20, 30, 40, 50, 60, 90}

# %%
sorted(a)
# Out:
# [20, 30, 40, 50, 60, 90]

# %%
sorted(a, reverse =True)
# Out:
# [90, 60, 50, 40, 30, 20]

# %%
a|b
# Out:
# {20, 30, 40, 50, 60, 70, 90}

# %%
a|(b,c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 a|(b,c)
#
# NameError: name 'c' is not defined

# %%
a.intersection(b)
# Out:
# {20, 30, 40, 50, 60, 90}

# %%
a & b
# Out:
# {20, 30, 40, 50, 60, 90}

# %%
a-b
# Out:
# set()

# %%
b-a
# Out:
# {70}

# %%
t
# Out:
# (10, 20, 30, 40, 50, 60, 100)

# %%
t[:33]
# Out:
# (10, 20, 30, 40, 50, 60, 100)

# %%
t[:1]
# Out:
# (10,)

# %%
t[:-1]
# Out:
# (10, 20, 30, 40, 50, 60)

# %%
t[::4]
# Out:
# (10, 50)
